# %% [markdown]
# # BBT 3201: Artificial Intelligence — Practical Exercise 1
#
# **File:** `Python_Refresher.ipynb`
#
# Each question is in its own cell. Replace the placeholders with your final code and add comments explaining your logic.

# %% [markdown]
# ### Question 1
# Write a program that asks the user for a number of days. The program then prints out the number of seconds in the amount of days given.

# %%
hours_in_day = 24          # Number of hours in one day
minutes_in_hour = 60       # Number of minutes in one hour
seconds_in_minute = 60     # Number of seconds in one minute

# Ask the user to enter the number of days
num_days = int(input("Enter the number of days: "))

# Calculate total seconds using the formula
# total_seconds = days × hours × minutes × seconds
total_seconds = num_days * hours_in_day * minutes_in_hour * seconds_in_minute

# Display the result 
print("Total seconds in %d day(s) = %d" % (num_days, total_seconds))
# Out:
# Total seconds in 5 day(s) = 432000

# %% [markdown]
# ### Question 2
# Write a program that asks a user to input the radius then the program calculates the volume of a sphere.
# Formula: \( V = \frac{4}{3}\pi r^3 \). Use the exponent operator for \(r^3\).

# %%
# Take integer input from the user
m = int(input("Enter the value of m: "))

# Construct the numbers mm (m repeated twice) and mmm (m repeated thrice)
# For Example: if m = 4, mm = 44
mm = int(str(m) * 2)    

# For Example: if m = 4, mmm = 444
mmm = int(str(m) * 3)   


# Display intermediate values for clarity
print("Step 1: m =", m)
print("Step 2: mm =", mm)
print("Step 3: mmm =", mmm)

# Compute the final result
value = m + mm + mmm

# Display the result
print("Final Step: m + mm + mmm =", value)
# Out:
# Step 1: m = 5
# Step 2: mm = 55
# Step 3: mmm = 555
# Final Step: m + mm + mmm = 615

# %% [markdown]
# ### Question 3
# Using functions, write a program to compute the area and perimeter of a square.
# Prompt the user for the side length and display both values.

# %%
# First we take input from the user
side = float(input("Enter the side of the square: "))

# We then Calculate area (side × side)
area = side * side

# Calculate perimeter (4 × side)
perimeter = 4 * side

# Step 4: Display the results
print("Perimeter =", perimeter, "and Area =", area)
# Out:
# Perimeter = 272.0 and Area = 4624.0

# %% [markdown]
# ### Question 4
# Write a program using functions that determines whether a character input by a user is uppercase or lowercase.

# %%
# First I took a  character input from the user
ch = input("Enter any character: ")

# Next I Checked if the character is in lowercase
if ch.islower():
    print("You entered a Lowercase Letter")

# Finally I Checked if the character is in uppercase
if ch.isupper():
    print("You entered an Uppercase Letter")
# Out:
# You entered a Lowercase Letter

# %% [markdown]
# ### Question 5
# Translate the following pseudocode into Python:
#
# ```
# BEGIN
# SET x TO 0, y TO 20
# REPEAT
#   SUBTRACT 4 FROM y
#   ADD 2/y TO x
# UNTIL y IS LESS THAN 6
# DISPLAY x
# END
# ```

# %%
# I started  with the given values
x = 0
y = 20

# I Kept repeating until y becomes less than 6
while y >= 6:
    y = y - 4        # This line of code subtracts 4 from y
    x = x + (2 / y)  # This line of code adds 2/y to x


print("Final x =", x)
# Out:
# Final x = 1.0416666666666665

# %% [markdown]
# ### Question 6
# - Use a loop to let the user input **5 values** and store them in a list/array.
# - Calculate and display the **average** of the values.

# %%
# Sum and average of 5 numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
d = int(input("Enter fourth number: "))
e = int(input("Enter fifth number: "))

sum = a + b + c + d + e
avg = sum / 5

print("Sum =", sum)
print("Average =", avg)
# Out:
# Sum = 23
# Average = 4.6

# %% [markdown]
# ### Question 7 — Codility Data Structures Challenge
# - Add a screenshot of your solution and analysis.
# - You can either drag & drop the image into this notebook (if supported), or upload the image file next to the notebook and display it with the code below.

# %%
###  Codility Data Structures Challenge (AbsDistinct task)

##Below is the evidence of my Codility solution and analysis .  


from IPython.display import Image, display
display(Image("codility.png"))
